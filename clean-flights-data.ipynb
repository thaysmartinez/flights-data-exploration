# %% [markdown]
# ## Clean Delayed Flights Data

# %%
# Import all packages
import pandas as pd
import numpy as np
from datetime import datetime, date

# %%
flights_raw = '/Users/thaysmartinez/Documents/Flights Data Exploration/flights_raw.csv'
df_delayed = pd.read_csv(flights_raw)

# %%
# Filter DataFrame with delayed flights
df_delayed = df_delayed.query('CANCELLED == 0 & ARR_DELAY > 0')

# %%
df_delayed.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5017439 entries, 0 to 14635477
# Data columns (total 28 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   FL_DATE              5017439 non-null  object
#  1   ORIGIN               5017439 non-null  object
#  2   ORIGIN_CITY_NAME     5017439 non-null  object
#  3   DEST                 5017439 non-null  object
#  4   DEST_CITY_NAME       5017439 non-null  object
#  5   CRS_DEP_TIME         5017439 non-null  int64
#  6   DEP_TIME             5017439 non-null  float64
#  7   DEP_DELAY            5016242 non-null  float64
#  8   TAXI_OUT             5017439 non-null  float64
#  9   WHEELS_OFF           5017439 non-null  float64
#  10  WHEELS_ON            5017439 non-null  float64
#  11  TAXI_IN              5017439 non-null  float64
#  12  CRS_ARR_TIME         5017439 non-null  int64
#  13  ARR_TIME             5017439 non-null  float64
#  14  ARR_DELAY            5017439 non-null  float64
#  15  CANCELLED            5017439 non-null  float64
#  16  CANCELLATION_CODE    0 non-null        object
#  17  DIVERTED             5017439 non-null  float64
#  18  CRS_ELAPSED_TIME     5017439 non-null  float64
#  19  ACTUAL_ELAPSED_TIME  5017438 non-null  float64
#  20  AIR_TIME             5017438 non-null  float64
#  21  DISTANCE             5017439 non-null  float64
#  22  CARRIER_DELAY        2741963 non-null  float64
#  23  WEATHER_DELAY        2741963 non-null  float64
#  24  NAS_DELAY            2741963 non-null  float64
#  25  SECURITY_DELAY       2741963 non-null  float64
#  26  LATE_AIRCRAFT_DELAY  2741963 non-null  float64
#  27  Unnamed: 27          0 non-null        float64
# dtypes: float64(20), int64(2), object(6)
# memory usage: 1.1+ GB

# %%
pd.set_option('display.max_columns', 30)
df_delayed.head()
# Out:
#       FL_DATE ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  CRS_DEP_TIME  \
# 0  2019-03-01    CVG   Cincinnati, OH  MSP  Minneapolis, MN          1534
# 1  2019-03-01    JFK     New York, NY  BUF      Buffalo, NY           940
# 2  2019-03-01    MSN      Madison, WI  LGA     New York, NY          1845
# 4  2019-03-01    JFK     New York, NY  BUF      Buffalo, NY          1336
# 6  2019-03-01    ATL      Atlanta, GA  TYS    Knoxville, TN          1340
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  \
# 0    1617.0       43.0      28.0      1645.0     1729.0     18.0
# 1    1035.0       55.0      56.0      1131.0     1228.0      8.0
# 2    1954.0       69.0      14.0      2008.0     2259.0     13.0
# 4    1530.0      114.0      30.0      1600.0     1652.0      6.0
# 6    1425.0       45.0      18.0      1443.0     1517.0      3.0
#
#    CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0          1648    1747.0       59.0        0.0               NaN       0.0
# 1          1114    1236.0       82.0        0.0               NaN       0.0
# 2          2158    2312.0       74.0        0.0               NaN       0.0
# 4          1513    1658.0      105.0        0.0               NaN       0.0
# 6          1438    1520.0       42.0        0.0               NaN       0.0
#
#    CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 0             134.0                150.0     104.0     596.0            0.0
# 1              94.0                121.0      57.0     301.0            0.0
# 2             133.0                138.0     111.0     812.0            0.0
# 4              97.0                 88.0      52.0     301.0           35.0
# 6              58.0                 55.0      34.0     152.0           42.0
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0            0.0       59.0             0.0                  0.0          NaN
# 1           55.0       27.0             0.0                  0.0          NaN
# 2            0.0        6.0             0.0                 68.0          NaN
# 4            0.0        0.0             0.0                 70.0          NaN
# 6            0.0        0.0             0.0                  0.0          NaN

# %%
# Lowercase columns
df_delayed.columns = map(str.lower, df_delayed.columns)

# %%
# Rename columns
df_delayed.rename(columns={'origin': 'origin_airport', 
                           'dest': 'dest_airport', 
                           'origin_city_name': 'origin_city', 
                           'dest_city_name': 'dest_city', 
                           'dep_time': 'actual_dep_time', 
                           'arr_time': 'actual_arr_time',
                           'cancellation_code': 'cancellation_desc'},
                  errors='raise', inplace=True)

# %%
# Convert flight date to datetime data type
df_delayed['fl_date'] = pd.to_datetime(df_delayed['fl_date'])

# %%
# Convert columns from numeric to object types and pad zeroes
columns = ['crs_dep_time', 'actual_dep_time', 'wheels_off', 
           'wheels_on', 'crs_arr_time', 'actual_arr_time']

converter = (lambda x: x.astype(str)
                        .str.replace(r'(\.0)$', '')
                        .str.zfill(4)
                        .str.replace('2400', '0000')
               if x.name in columns else x)

df_delayed = df_delayed.apply(converter)

# %%
# Convert columns to time timestamp
for column in columns:
    df_delayed[column] = df_delayed[column].apply(lambda x: datetime.strptime(x, '%H%M').time())

# %%
# Apply timedelta
time_diff = lambda x: datetime.combine(date.min, x)
df_delayed['dep_delay'] = (df_delayed['actual_dep_time'].apply(time_diff) 
                           - df_delayed['crs_dep_time'].apply(time_diff))

df_delayed['actual_elapsed_time'] = (df_delayed['actual_arr_time'].apply(time_diff) 
                                     - df_delayed['actual_dep_time'].apply(time_diff))

df_delayed['air_time'] = (df_delayed['crs_arr_time'].apply(time_diff) 
                          - df_delayed['crs_dep_time'].apply(time_diff))

# %%
# Convert to minutes
columns = ['dep_delay', 'actual_elapsed_time', 'air_time']

for column in columns:
    ls_min = []
    for item in df_delayed[column]:
        ls_min.append(item.total_seconds()/60)
    
    df_delayed[column] = ls_min

# %%
df_delayed.head()
# Out:
#      fl_date origin_airport     origin_city dest_airport        dest_city  \
# 0 2019-03-01            CVG  Cincinnati, OH          MSP  Minneapolis, MN
# 1 2019-03-01            JFK    New York, NY          BUF      Buffalo, NY
# 2 2019-03-01            MSN     Madison, WI          LGA     New York, NY
# 4 2019-03-01            JFK    New York, NY          BUF      Buffalo, NY
# 6 2019-03-01            ATL     Atlanta, GA          TYS    Knoxville, TN
#
#   crs_dep_time actual_dep_time  dep_delay  taxi_out wheels_off wheels_on  \
# 0     15:34:00        16:17:00       43.0      28.0   16:45:00  17:29:00
# 1     09:40:00        10:35:00       55.0      56.0   11:31:00  12:28:00
# 2     18:45:00        19:54:00       69.0      14.0   20:08:00  22:59:00
# 4     13:36:00        15:30:00      114.0      30.0   16:00:00  16:52:00
# 6     13:40:00        14:25:00       45.0      18.0   14:43:00  15:17:00
#
#    taxi_in crs_arr_time actual_arr_time  arr_delay  cancelled  \
# 0     18.0     16:48:00        17:47:00       59.0        0.0
# 1      8.0     11:14:00        12:36:00       82.0        0.0
# 2     13.0     21:58:00        23:12:00       74.0        0.0
# 4      6.0     15:13:00        16:58:00      105.0        0.0
# 6      3.0     14:38:00        15:20:00       42.0        0.0
#
#   cancellation_desc  diverted  crs_elapsed_time  actual_elapsed_time  \
# 0               NaN       0.0             134.0                 90.0
# 1               NaN       0.0              94.0                121.0
# 2               NaN       0.0             133.0                198.0
# 4               NaN       0.0              97.0                 88.0
# 6               NaN       0.0              58.0                 55.0
#
#    air_time  distance  carrier_delay  weather_delay  nas_delay  \
# 0      74.0     596.0            0.0            0.0       59.0
# 1      94.0     301.0            0.0           55.0       27.0
# 2     193.0     812.0            0.0            0.0        6.0
# 4      97.0     301.0           35.0            0.0        0.0
# 6      58.0     152.0           42.0            0.0        0.0
#
#    security_delay  late_aircraft_delay  unnamed: 27
# 0             0.0                  0.0          NaN
# 1             0.0                  0.0          NaN
# 2             0.0                 68.0          NaN
# 4             0.0                 70.0          NaN
# 6             0.0                  0.0          NaN

# %%
# Convert to int
columns = ['dep_delay', 'taxi_out', 'taxi_in', 'arr_delay', 'cancelled',
           'diverted', 'crs_elapsed_time', 'actual_elapsed_time', 
           'air_time', 'distance']

convert_int = lambda x: x.astype(int) if x.name in columns else x

df_delayed = df_delayed.apply(convert_int)

# %%
df_delayed.head()
# Out:
#      fl_date origin_airport     origin_city dest_airport        dest_city  \
# 0 2019-03-01            CVG  Cincinnati, OH          MSP  Minneapolis, MN
# 1 2019-03-01            JFK    New York, NY          BUF      Buffalo, NY
# 2 2019-03-01            MSN     Madison, WI          LGA     New York, NY
# 4 2019-03-01            JFK    New York, NY          BUF      Buffalo, NY
# 6 2019-03-01            ATL     Atlanta, GA          TYS    Knoxville, TN
#
#   crs_dep_time actual_dep_time  dep_delay  taxi_out wheels_off wheels_on  \
# 0     15:34:00        16:17:00         43        28   16:45:00  17:29:00
# 1     09:40:00        10:35:00         55        56   11:31:00  12:28:00
# 2     18:45:00        19:54:00         69        14   20:08:00  22:59:00
# 4     13:36:00        15:30:00        114        30   16:00:00  16:52:00
# 6     13:40:00        14:25:00         45        18   14:43:00  15:17:00
#
#    taxi_in crs_arr_time actual_arr_time  arr_delay  cancelled  \
# 0       18     16:48:00        17:47:00         59          0
# 1        8     11:14:00        12:36:00         82          0
# 2       13     21:58:00        23:12:00         74          0
# 4        6     15:13:00        16:58:00        105          0
# 6        3     14:38:00        15:20:00         42          0
#
#   cancellation_desc  diverted  crs_elapsed_time  actual_elapsed_time  \
# 0               NaN         0               134                   90
# 1               NaN         0                94                  121
# 2               NaN         0               133                  198
# 4               NaN         0                97                   88
# 6               NaN         0                58                   55
#
#    air_time  distance  carrier_delay  weather_delay  nas_delay  \
# 0        74       596            0.0            0.0       59.0
# 1        94       301            0.0           55.0       27.0
# 2       193       812            0.0            0.0        6.0
# 4        97       301           35.0            0.0        0.0
# 6        58       152           42.0            0.0        0.0
#
#    security_delay  late_aircraft_delay  unnamed: 27
# 0             0.0                  0.0          NaN
# 1             0.0                  0.0          NaN
# 2             0.0                 68.0          NaN
# 4             0.0                 70.0          NaN
# 6             0.0                  0.0          NaN

# %%
df_delayed.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5017439 entries, 0 to 14635477
# Data columns (total 28 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   fl_date              5017439 non-null  datetime64[ns]
#  1   origin_airport       5017439 non-null  object
#  2   origin_city          5017439 non-null  object
#  3   dest_airport         5017439 non-null  object
#  4   dest_city            5017439 non-null  object
#  5   crs_dep_time         5017439 non-null  object
#  6   actual_dep_time      5017439 non-null  object
#  7   dep_delay            5017439 non-null  int64
#  8   taxi_out             5017439 non-null  int64
#  9   wheels_off           5017439 non-null  object
#  10  wheels_on            5017439 non-null  object
#  11  taxi_in              5017439 non-null  int64
#  12  crs_arr_time         5017439 non-null  object
#  13  actual_arr_time      5017439 non-null  object
#  14  arr_delay            5017439 non-null  int64
#  15  cancelled            5017439 non-null  int64
#  16  cancellation_desc    0 non-null        object
#  17  diverted             5017439 non-null  int64
#  18  crs_elapsed_time     5017439 non-null  int64
#  19  actual_elapsed_time  5017439 non-null  int64
#  20  air_time             5017439 non-null  int64
#  21  distance             5017439 non-null  int64
#  22  carrier_delay        2741963 non-null  float64
#  23  weather_delay        2741963 non-null  float64
#  24  nas_delay            2741963 non-null  float64
#  25  security_delay       2741963 non-null  float64
#  26  late_aircraft_delay  2741963 non-null  float64
#  27  unnamed: 27          0 non-null        float64
# dtypes: datetime64[ns](1), float64(6), int64(10), object(11)
# memory usage: 1.1+ GB

# %% [markdown]
# ## Clean Cancelled Flights

# %%
# Read file into DataFrame
df_cancelled = pd.read_csv(flights_raw)

# %%
# Display first rows
pd.set_option('display.max_columns', 30)
df_cancelled.head()
# Out:
#       FL_DATE ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  CRS_DEP_TIME  \
# 0  2019-03-01    CVG   Cincinnati, OH  MSP  Minneapolis, MN          1534
# 1  2019-03-01    JFK     New York, NY  BUF      Buffalo, NY           940
# 2  2019-03-01    MSN      Madison, WI  LGA     New York, NY          1845
# 3  2019-03-01    TYS    Knoxville, TN  DTW      Detroit, MI           735
# 4  2019-03-01    JFK     New York, NY  BUF      Buffalo, NY          1336
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  \
# 0    1617.0       43.0      28.0      1645.0     1729.0     18.0
# 1    1035.0       55.0      56.0      1131.0     1228.0      8.0
# 2    1954.0       69.0      14.0      2008.0     2259.0     13.0
# 3     729.0       -6.0      15.0       744.0      855.0      8.0
# 4    1530.0      114.0      30.0      1600.0     1652.0      6.0
#
#    CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0          1648    1747.0       59.0        0.0               NaN       0.0
# 1          1114    1236.0       82.0        0.0               NaN       0.0
# 2          2158    2312.0       74.0        0.0               NaN       0.0
# 3           925     903.0      -22.0        0.0               NaN       0.0
# 4          1513    1658.0      105.0        0.0               NaN       0.0
#
#    CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 0             134.0                150.0     104.0     596.0            0.0
# 1              94.0                121.0      57.0     301.0            0.0
# 2             133.0                138.0     111.0     812.0            0.0
# 3             110.0                 94.0      71.0     443.0            NaN
# 4              97.0                 88.0      52.0     301.0           35.0
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0            0.0       59.0             0.0                  0.0          NaN
# 1           55.0       27.0             0.0                  0.0          NaN
# 2            0.0        6.0             0.0                 68.0          NaN
# 3            NaN        NaN             NaN                  NaN          NaN
# 4            0.0        0.0             0.0                 70.0          NaN

# %%
# Lowercase columns
df_cancelled.columns = map(str.lower, df_cancelled.columns)

# %%
# Create DataFrame with cancelled flights
df_cancelled = df_cancelled.query('cancelled == 1')

# %%
# Convert flight date to datetime data type
df_cancelled['fl_date'] = pd.to_datetime(df_cancelled['fl_date'])

# %%
# Rename columns
df_cancelled.rename(columns={'origin': 'origin_airport', 
                             'dest': 'dest_airport', 
                             'origin_city_name': 'origin_city', 
                             'dest_city_name': 'dest_city', 
                             'dep_time': 'actual_dep_time', 
                             'arr_time': 'actual_arr_time',
                             'cancellation_code': 'cancellation_desc'},
                  errors='raise', inplace=True)

# %%
# Convert columns from numeric to object types and pad zeroes
columns = ['crs_dep_time', 'crs_arr_time']

converter = (lambda x: x.astype(str)
                        .str.zfill(4)
                        .str.replace('2400', '0000')
               if x.name in columns else x)

df_cancelled = df_cancelled.apply(converter)

# %%
# Convert columns to time timestamp
for column in columns:
    df_cancelled[column] = df_cancelled[column].apply(lambda x: datetime.strptime(x, '%H%M').time())

# %%
# Apply timedelta
time_diff = lambda x: datetime.combine(date.min, x)
df_cancelled['crs_elapsed_time'] = (df_cancelled['crs_arr_time'].apply(time_diff) 
                                    - df_cancelled['crs_dep_time'].apply(time_diff))

# %%
# Convert to minutes
ls_minutes = []
for item in df_cancelled['crs_elapsed_time']:
    ls_minutes.append(item.total_seconds()/60)

df_cancelled['crs_elapsed_time'] = ls_minutes

# %%
df_cancelled.head()
# Out:
#        fl_date origin_airport            origin_city dest_airport  \
# 230 2019-03-01            ORF            Norfolk, VA          LGA
# 250 2019-03-01            CHO    Charlottesville, VA          CLT
# 251 2019-03-01            CLT          Charlotte, NC          CHO
# 366 2019-03-01            GSP              Greer, SC          ORD
# 418 2019-03-01            DFW  Dallas/Fort Worth, TX          CRP
#
#                dest_city crs_dep_time  actual_dep_time  dep_delay  taxi_out  \
# 230         New York, NY     18:55:00              NaN        NaN       NaN
# 250        Charlotte, NC     19:40:00              NaN        NaN       NaN
# 251  Charlottesville, VA     17:55:00              NaN        NaN       NaN
# 366          Chicago, IL     10:11:00              NaN        NaN       NaN
# 418   Corpus Christi, TX     20:43:00           2128.0       45.0      20.0
#
#      wheels_off  wheels_on  taxi_in crs_arr_time  actual_arr_time  arr_delay  \
# 230         NaN        NaN      NaN     20:42:00              NaN        NaN
# 250         NaN        NaN      NaN     21:05:00              NaN        NaN
# 251         NaN        NaN      NaN     19:10:00              NaN        NaN
# 366         NaN        NaN      NaN     11:15:00              NaN        NaN
# 418      2148.0        NaN      NaN     22:07:00              NaN        NaN
#
#      cancelled cancellation_desc  diverted  crs_elapsed_time  \
# 230        1.0                 B       0.0             107.0
# 250        1.0                 B       0.0              85.0
# 251        1.0                 B       0.0              75.0
# 366        1.0                 B       0.0              64.0
# 418        1.0                 B       0.0              84.0
#
#      actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 230                  NaN       NaN     296.0            NaN            NaN
# 250                  NaN       NaN     245.0            NaN            NaN
# 251                  NaN       NaN     245.0            NaN            NaN
# 366                  NaN       NaN     577.0            NaN            NaN
# 418                  NaN       NaN     354.0            NaN            NaN
#
#      nas_delay  security_delay  late_aircraft_delay  unnamed: 27
# 230        NaN             NaN                  NaN          NaN
# 250        NaN             NaN                  NaN          NaN
# 251        NaN             NaN                  NaN          NaN
# 366        NaN             NaN                  NaN          NaN
# 418        NaN             NaN                  NaN          NaN

# %%
# Convert to int
columns = ['cancelled', 'diverted', 'crs_elapsed_time', 'distance']
converter = (lambda x: x.astype(int) if x.name in columns else x)

df_cancelled = df_cancelled.apply(converter)

# %%
# Assign nulls to columns not used
df_cancelled[['actual_dep_time', 'dep_delay', 'taxi_out', 
              'wheels_off', 'wheels_on', 'taxi_in', 
              'actual_arr_time', 'arr_delay', 'actual_elapsed_time', 'air_time',
              'carrier_delay', 'weather_delay', 'nas_delay', 'security_delay',
              'late_aircraft_delay']] = np.nan

# %%
df_cancelled.head()
# Out:
#        fl_date origin_airport            origin_city dest_airport  \
# 230 2019-03-01            ORF            Norfolk, VA          LGA
# 250 2019-03-01            CHO    Charlottesville, VA          CLT
# 251 2019-03-01            CLT          Charlotte, NC          CHO
# 366 2019-03-01            GSP              Greer, SC          ORD
# 418 2019-03-01            DFW  Dallas/Fort Worth, TX          CRP
#
#                dest_city crs_dep_time  actual_dep_time  dep_delay  taxi_out  \
# 230         New York, NY     18:55:00              NaN        NaN       NaN
# 250        Charlotte, NC     19:40:00              NaN        NaN       NaN
# 251  Charlottesville, VA     17:55:00              NaN        NaN       NaN
# 366          Chicago, IL     10:11:00              NaN        NaN       NaN
# 418   Corpus Christi, TX     20:43:00              NaN        NaN       NaN
#
#      wheels_off  wheels_on  taxi_in crs_arr_time  actual_arr_time  arr_delay  \
# 230         NaN        NaN      NaN     20:42:00              NaN        NaN
# 250         NaN        NaN      NaN     21:05:00              NaN        NaN
# 251         NaN        NaN      NaN     19:10:00              NaN        NaN
# 366         NaN        NaN      NaN     11:15:00              NaN        NaN
# 418         NaN        NaN      NaN     22:07:00              NaN        NaN
#
#      cancelled cancellation_desc  diverted  crs_elapsed_time  \
# 230          1                 B         0               107
# 250          1                 B         0                85
# 251          1                 B         0                75
# 366          1                 B         0                64
# 418          1                 B         0                84
#
#      actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 230                  NaN       NaN       296            NaN            NaN
# 250                  NaN       NaN       245            NaN            NaN
# 251                  NaN       NaN       245            NaN            NaN
# 366                  NaN       NaN       577            NaN            NaN
# 418                  NaN       NaN       354            NaN            NaN
#
#      nas_delay  security_delay  late_aircraft_delay  unnamed: 27
# 230        NaN             NaN                  NaN          NaN
# 250        NaN             NaN                  NaN          NaN
# 251        NaN             NaN                  NaN          NaN
# 366        NaN             NaN                  NaN          NaN
# 418        NaN             NaN                  NaN          NaN

# %%
# Replace cancellation codes with descriptions
cancellation_desc = {'A': 'Carrier',
                     'B': 'Weather',
                     'C': 'NAS',
                     'D': 'Security'}

ls_canc = []
for item in df_cancelled['cancellation_desc']:
    if item in cancellation_desc:
        ls_canc.append(cancellation_desc[item])

df_cancelled['cancellation_desc'] = ls_canc

# %%
# Display resulting DataFrame
df_cancelled.head()
# Out:
#        fl_date origin_airport            origin_city dest_airport  \
# 230 2019-03-01            ORF            Norfolk, VA          LGA
# 250 2019-03-01            CHO    Charlottesville, VA          CLT
# 251 2019-03-01            CLT          Charlotte, NC          CHO
# 366 2019-03-01            GSP              Greer, SC          ORD
# 418 2019-03-01            DFW  Dallas/Fort Worth, TX          CRP
#
#                dest_city crs_dep_time  actual_dep_time  dep_delay  taxi_out  \
# 230         New York, NY     18:55:00              NaN        NaN       NaN
# 250        Charlotte, NC     19:40:00              NaN        NaN       NaN
# 251  Charlottesville, VA     17:55:00              NaN        NaN       NaN
# 366          Chicago, IL     10:11:00              NaN        NaN       NaN
# 418   Corpus Christi, TX     20:43:00              NaN        NaN       NaN
#
#      wheels_off  wheels_on  taxi_in crs_arr_time  actual_arr_time  arr_delay  \
# 230         NaN        NaN      NaN     20:42:00              NaN        NaN
# 250         NaN        NaN      NaN     21:05:00              NaN        NaN
# 251         NaN        NaN      NaN     19:10:00              NaN        NaN
# 366         NaN        NaN      NaN     11:15:00              NaN        NaN
# 418         NaN        NaN      NaN     22:07:00              NaN        NaN
#
#      cancelled cancellation_desc  diverted  crs_elapsed_time  \
# 230          1           Weather         0               107
# 250          1           Weather         0                85
# 251          1           Weather         0                75
# 366          1           Weather         0                64
# 418          1           Weather         0                84
#
#      actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 230                  NaN       NaN       296            NaN            NaN
# 250                  NaN       NaN       245            NaN            NaN
# 251                  NaN       NaN       245            NaN            NaN
# 366                  NaN       NaN       577            NaN            NaN
# 418                  NaN       NaN       354            NaN            NaN
#
#      nas_delay  security_delay  late_aircraft_delay  unnamed: 27
# 230        NaN             NaN                  NaN          NaN
# 250        NaN             NaN                  NaN          NaN
# 251        NaN             NaN                  NaN          NaN
# 366        NaN             NaN                  NaN          NaN
# 418        NaN             NaN                  NaN          NaN

# %%
# Append dataframe
flights = df_delayed.append(df_cancelled).reset_index(drop=True)

# %%
# Split columns
flights[['origin_city', 'origin_state']] = flights.origin_city.str.split(',', expand=True)
flights[['dest_city', 'dest_state']] = flights.dest_city.str.split(',', expand=True)

# %%
# Drop unnamed:27
flights.drop(columns=['unnamed: 27'], inplace=True)

# %%
# Reorder columns
ordered_columns = ['fl_date', 'origin_airport', 'origin_city', 'origin_state', 
                   'dest_airport', 'dest_city', 'dest_state', 'crs_dep_time', 
                   'actual_dep_time', 'dep_delay', 'taxi_out', 'wheels_off', 
                   'wheels_on', 'taxi_in', 'crs_arr_time', 'actual_arr_time', 
                   'arr_delay', 'cancelled', 'cancellation_desc', 'diverted',
                   'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 
                   'distance', 'carrier_delay', 'weather_delay', 'nas_delay', 
                   'security_delay', 'late_aircraft_delay', ]

flights = flights[ordered_columns]

# %%
flights.head()
# Out:
#      fl_date origin_airport origin_city origin_state dest_airport  \
# 0 2019-03-01            CVG  Cincinnati           OH          MSP
# 1 2019-03-01            JFK    New York           NY          BUF
# 2 2019-03-01            MSN     Madison           WI          LGA
# 3 2019-03-01            JFK    New York           NY          BUF
# 4 2019-03-01            ATL     Atlanta           GA          TYS
#
#      dest_city dest_state crs_dep_time actual_dep_time  dep_delay  taxi_out  \
# 0  Minneapolis         MN     15:34:00        16:17:00       43.0      28.0
# 1      Buffalo         NY     09:40:00        10:35:00       55.0      56.0
# 2     New York         NY     18:45:00        19:54:00       69.0      14.0
# 3      Buffalo         NY     13:36:00        15:30:00      114.0      30.0
# 4    Knoxville         TN     13:40:00        14:25:00       45.0      18.0
#
#   wheels_off wheels_on  taxi_in crs_arr_time actual_arr_time  arr_delay  \
# 0   16:45:00  17:29:00     18.0     16:48:00        17:47:00       59.0
# 1   11:31:00  12:28:00      8.0     11:14:00        12:36:00       82.0
# 2   20:08:00  22:59:00     13.0     21:58:00        23:12:00       74.0
# 3   16:00:00  16:52:00      6.0     15:13:00        16:58:00      105.0
# 4   14:43:00  15:17:00      3.0     14:38:00        15:20:00       42.0
#
#    cancelled cancellation_desc  diverted  crs_elapsed_time  \
# 0          0               NaN         0               134
# 1          0               NaN         0                94
# 2          0               NaN         0               133
# 3          0               NaN         0                97
# 4          0               NaN         0                58
#
#    actual_elapsed_time  air_time  distance  carrier_delay  weather_delay  \
# 0                 90.0      74.0       596            0.0            0.0
# 1                121.0      94.0       301            0.0           55.0
# 2                198.0     193.0       812            0.0            0.0
# 3                 88.0      97.0       301           35.0            0.0
# 4                 55.0      58.0       152           42.0            0.0
#
#    nas_delay  security_delay  late_aircraft_delay
# 0       59.0             0.0                  0.0
# 1       27.0             0.0                  0.0
# 2        6.0             0.0                 68.0
# 3        0.0             0.0                 70.0
# 4        0.0             0.0                  0.0

# %%
flights.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268948 entries, 0 to 5268947
# Data columns (total 29 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   fl_date              5268948 non-null  datetime64[ns]
#  1   origin_airport       5268948 non-null  object
#  2   origin_city          5268948 non-null  object
#  3   origin_state         5268948 non-null  object
#  4   dest_airport         5268948 non-null  object
#  5   dest_city            5268948 non-null  object
#  6   dest_state           5268948 non-null  object
#  7   crs_dep_time         5268948 non-null  object
#  8   actual_dep_time      5017439 non-null  object
#  9   dep_delay            5017439 non-null  float64
#  10  taxi_out             5017439 non-null  float64
#  11  wheels_off           5017439 non-null  object
#  12  wheels_on            5017439 non-null  object
#  13  taxi_in              5017439 non-null  float64
#  14  crs_arr_time         5268948 non-null  object
#  15  actual_arr_time      5017439 non-null  object
#  16  arr_delay            5017439 non-null  float64
#  17  cancelled            5268948 non-null  int64
#  18  cancellation_desc    251509 non-null   object
#  19  diverted             5268948 non-null  int64
#  20  crs_elapsed_time     5268948 non-null  int64
#  21  actual_elapsed_time  5017439 non-null  float64
#  22  air_time             5017439 non-null  float64
#  23  distance             5268948 non-null  int64
#  24  carrier_delay        2741963 non-null  float64
#  25  weather_delay        2741963 non-null  float64
#  26  nas_delay            2741963 non-null  float64
#  27  security_delay       2741963 non-null  float64
#  28  late_aircraft_delay  2741963 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(4), object(13)
# memory usage: 1.1+ GB

# %%
# Write to csv
dest_folder = '/Users/thaysmartinez/Documents/Flights Data Exploration/'
extension = '.csv'
flights.to_csv('%sflights%s' % (dest_folder, extension), index=False, encoding='utf-8')
