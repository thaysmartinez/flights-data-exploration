# %% [markdown]
# ## Clean Delayed Flights Data

# %%
# Import all packages
import pandas as pd
import numpy as np
from datetime import datetime, date

# %%
# Load data
flights_raw = '/Users/thaysmartinez/Documents/Flights Data Exploration/flights_raw.csv'
df_sample = pd.read_csv(flights_raw)

# %%
# Load sample
df_sample = df_sample.sample(n=500000, random_state=42)

# %%
# Create copy
flights = df_sample.copy()

# %%
# Filter DataFrame with finalized flights
df1 = flights.query('CANCELLED == 0 & DIVERTED == 0').reset_index(drop=True)

# %%
df1.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491127 entries, 0 to 491126
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FL_DATE              491127 non-null  object
#  1   ORIGIN               491127 non-null  object
#  2   ORIGIN_CITY_NAME     491127 non-null  object
#  3   DEST                 491127 non-null  object
#  4   DEST_CITY_NAME       491127 non-null  object
#  5   CRS_DEP_TIME         491127 non-null  int64
#  6   DEP_TIME             491127 non-null  float64
#  7   DEP_DELAY            491060 non-null  float64
#  8   TAXI_OUT             491127 non-null  float64
#  9   WHEELS_OFF           491127 non-null  float64
#  10  WHEELS_ON            491127 non-null  float64
#  11  TAXI_IN              491127 non-null  float64
#  12  CRS_ARR_TIME         491127 non-null  int64
#  13  ARR_TIME             491127 non-null  float64
#  14  ARR_DELAY            491091 non-null  float64
#  15  CANCELLED            491127 non-null  float64
#  16  CANCELLATION_CODE    0 non-null       object
#  17  DIVERTED             491127 non-null  float64
#  18  CRS_ELAPSED_TIME     491127 non-null  float64
#  19  ACTUAL_ELAPSED_TIME  491127 non-null  float64
#  20  AIR_TIME             491127 non-null  float64
#  21  DISTANCE             491127 non-null  float64
#  22  CARRIER_DELAY        91316 non-null   float64
#  23  WEATHER_DELAY        91316 non-null   float64
#  24  NAS_DELAY            91316 non-null   float64
#  25  SECURITY_DELAY       91316 non-null   float64
#  26  LATE_AIRCRAFT_DELAY  91316 non-null   float64
#  27  Unnamed: 27          0 non-null       float64
# dtypes: float64(20), int64(2), object(6)
# memory usage: 104.9+ MB

# %%
pd.set_option('display.max_columns', 30)
df1.head()
# Out:
#       FL_DATE ORIGIN ORIGIN_CITY_NAME DEST         DEST_CITY_NAME  \
# 0  2019-01-30    FNT        Flint, MI  ATL            Atlanta, GA
# 1  2019-10-18    CMH     Columbus, OH  MIA              Miami, FL
# 2  2016-11-18    MIA        Miami, FL  LAX        Los Angeles, CA
# 3  2019-05-13    LRD       Laredo, TX  DFW  Dallas/Fort Worth, TX
# 4  2017-04-19    LAX  Los Angeles, CA  MSY        New Orleans, LA
#
#    CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  \
# 0           600     554.0       -6.0      38.0       632.0      814.0
# 1           657     713.0       16.0      23.0       736.0      948.0
# 2           730     731.0        1.0      17.0       748.0      948.0
# 3          1614    1616.0        2.0      15.0      1631.0     1730.0
# 4           925     940.0       15.0      16.0       956.0     1505.0
#
#    TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  \
# 0      4.0           820     818.0       -2.0        0.0               NaN
# 1      4.0           941     952.0       11.0        0.0               NaN
# 2     10.0          1016     958.0      -18.0        0.0               NaN
# 3      8.0          1745    1738.0       -7.0        0.0               NaN
# 4      2.0          1507    1507.0        0.0        0.0               NaN
#
#    DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0       0.0             140.0                144.0     102.0     645.0
# 1       0.0             164.0                159.0     132.0     990.0
# 2       0.0             346.0                327.0     300.0    2342.0
# 3       0.0              91.0                 82.0      59.0     396.0
# 4       0.0             222.0                207.0     189.0    1670.0
#
#    CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0            NaN            NaN        NaN             NaN
# 1            NaN            NaN        NaN             NaN
# 2            NaN            NaN        NaN             NaN
# 3            NaN            NaN        NaN             NaN
# 4            NaN            NaN        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN

# %%
# Lowercase columns
df1.columns = map(str.lower, df1.columns)

# %%
# Rename columns
dict_columns = {'fl_date': 'date', 
                'origin': 'dep_airport', 
                'origin_city_name': 'dep_city', 
                'dest': 'dest_airport', 
                'dest_city_name': 'dest_city',
                'cancelled': 'fl_type',
                'cancellation_code': 'canc_desc',
                'actual_elapsed_time': 'elapsed_time', 
                'carrier_delay': 'Carrier',
                'weather_delay': 'Weather', 
                'nas_delay': 'NAS', 
                'security_delay': 'Security', 
                'late_aircraft_delay': 'Late Aircraft'}


df1.rename(columns=dict_columns, errors='raise', inplace=True)

# %%
# Convert flight date to datetime data type
df1['date'] = pd.to_datetime(df1['date'])

# %%
# Convert columns from numeric to object types and pad zeroes
columns = ['crs_dep_time', 'dep_time', 'wheels_off', 
           'wheels_on', 'crs_arr_time', 'arr_time']

converter = (lambda x: x.astype(str)
                        .str.replace(r'(\.0)$', '')
                        .str.zfill(4)
                        .str.replace('2400', '0000')
             if x.name in columns else x)

df1 = df1.apply(converter)

# %%
# Convert columns to time timestamp
for column in columns:
    df1[column] = df1[column].apply(lambda x: datetime.strptime(x, '%H%M').time())

# %%
# Convert to int
columns = ['dep_delay', 'taxi_out', 'taxi_in', 'arr_delay', 'fl_type', 'diverted',
           'crs_elapsed_time', 'elapsed_time', 'air_time', 'distance']

convert_int = lambda x: x.fillna(0).astype(int) if x.name in columns else x

df1 = df1.apply(convert_int)

# %%
df1.head()
# Out:
#         date dep_airport         dep_city dest_airport              dest_city  \
# 0 2019-01-30         FNT        Flint, MI          ATL            Atlanta, GA
# 1 2019-10-18         CMH     Columbus, OH          MIA              Miami, FL
# 2 2016-11-18         MIA        Miami, FL          LAX        Los Angeles, CA
# 3 2019-05-13         LRD       Laredo, TX          DFW  Dallas/Fort Worth, TX
# 4 2017-04-19         LAX  Los Angeles, CA          MSY        New Orleans, LA
#
#   crs_dep_time  dep_time  dep_delay  taxi_out wheels_off wheels_on  taxi_in  \
# 0     06:00:00  05:54:00         -6        38   06:32:00  08:14:00        4
# 1     06:57:00  07:13:00         16        23   07:36:00  09:48:00        4
# 2     07:30:00  07:31:00          1        17   07:48:00  09:48:00       10
# 3     16:14:00  16:16:00          2        15   16:31:00  17:30:00        8
# 4     09:25:00  09:40:00         15        16   09:56:00  15:05:00        2
#
#   crs_arr_time  arr_time  arr_delay  fl_type canc_desc  diverted  \
# 0     08:20:00  08:18:00         -2        0       NaN         0
# 1     09:41:00  09:52:00         11        0       NaN         0
# 2     10:16:00  09:58:00        -18        0       NaN         0
# 3     17:45:00  17:38:00         -7        0       NaN         0
# 4     15:07:00  15:07:00          0        0       NaN         0
#
#    crs_elapsed_time  elapsed_time  air_time  distance  Carrier  Weather  NAS  \
# 0               140           144       102       645      NaN      NaN  NaN
# 1               164           159       132       990      NaN      NaN  NaN
# 2               346           327       300      2342      NaN      NaN  NaN
# 3                91            82        59       396      NaN      NaN  NaN
# 4               222           207       189      1670      NaN      NaN  NaN
#
#    Security  Late Aircraft  unnamed: 27
# 0       NaN            NaN          NaN
# 1       NaN            NaN          NaN
# 2       NaN            NaN          NaN
# 3       NaN            NaN          NaN
# 4       NaN            NaN          NaN

# %%
df1.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491127 entries, 0 to 491126
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              491127 non-null  datetime64[ns]
#  1   dep_airport       491127 non-null  object
#  2   dep_city          491127 non-null  object
#  3   dest_airport      491127 non-null  object
#  4   dest_city         491127 non-null  object
#  5   crs_dep_time      491127 non-null  object
#  6   dep_time          491127 non-null  object
#  7   dep_delay         491127 non-null  int64
#  8   taxi_out          491127 non-null  int64
#  9   wheels_off        491127 non-null  object
#  10  wheels_on         491127 non-null  object
#  11  taxi_in           491127 non-null  int64
#  12  crs_arr_time      491127 non-null  object
#  13  arr_time          491127 non-null  object
#  14  arr_delay         491127 non-null  int64
#  15  fl_type           491127 non-null  int64
#  16  canc_desc         0 non-null       object
#  17  diverted          491127 non-null  int64
#  18  crs_elapsed_time  491127 non-null  int64
#  19  elapsed_time      491127 non-null  int64
#  20  air_time          491127 non-null  int64
#  21  distance          491127 non-null  int64
#  22  Carrier           91316 non-null   float64
#  23  Weather           91316 non-null   float64
#  24  NAS               91316 non-null   float64
#  25  Security          91316 non-null   float64
#  26  Late Aircraft     91316 non-null   float64
#  27  unnamed: 27       0 non-null       float64
# dtypes: datetime64[ns](1), float64(6), int64(10), object(11)
# memory usage: 104.9+ MB

# %% [markdown]
# ## Clean Cancelled Flights

# %%
# Read file into DataFrame
df2 = df_sample.copy()

# %%
# Display first rows
pd.set_option('display.max_columns', 30)
df2.head()
# Out:
#              FL_DATE ORIGIN ORIGIN_CITY_NAME DEST         DEST_CITY_NAME  \
# 6482319   2019-01-30    FNT        Flint, MI  ATL            Atlanta, GA
# 10664859  2019-10-18    CMH     Columbus, OH  MIA              Miami, FL
# 19665024  2016-11-18    MIA        Miami, FL  LAX        Los Angeles, CA
# 9917058   2019-05-13    LRD       Laredo, TX  DFW  Dallas/Fort Worth, TX
# 5747941   2017-04-19    LAX  Los Angeles, CA  MSY        New Orleans, LA
#
#           CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  \
# 6482319            600     554.0       -6.0      38.0       632.0      814.0
# 10664859           657     713.0       16.0      23.0       736.0      948.0
# 19665024           730     731.0        1.0      17.0       748.0      948.0
# 9917058           1614    1616.0        2.0      15.0      1631.0     1730.0
# 5747941            925     940.0       15.0      16.0       956.0     1505.0
#
#           TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED  \
# 6482319       4.0           820     818.0       -2.0        0.0
# 10664859      4.0           941     952.0       11.0        0.0
# 19665024     10.0          1016     958.0      -18.0        0.0
# 9917058       8.0          1745    1738.0       -7.0        0.0
# 5747941       2.0          1507    1507.0        0.0        0.0
#
#          CANCELLATION_CODE  DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  \
# 6482319                NaN       0.0             140.0                144.0
# 10664859               NaN       0.0             164.0                159.0
# 19665024               NaN       0.0             346.0                327.0
# 9917058                NaN       0.0              91.0                 82.0
# 5747941                NaN       0.0             222.0                207.0
#
#           AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 6482319      102.0     645.0            NaN            NaN        NaN
# 10664859     132.0     990.0            NaN            NaN        NaN
# 19665024     300.0    2342.0            NaN            NaN        NaN
# 9917058       59.0     396.0            NaN            NaN        NaN
# 5747941      189.0    1670.0            NaN            NaN        NaN
#
#           SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 6482319              NaN                  NaN          NaN
# 10664859             NaN                  NaN          NaN
# 19665024             NaN                  NaN          NaN
# 9917058              NaN                  NaN          NaN
# 5747941              NaN                  NaN          NaN

# %%
# Lowercase columns
df2.columns = map(str.lower, df2.columns)

# %%
# Create DataFrame with cancelled flights
df2 = df2.query('cancelled == 1').reset_index(drop=True)

# %%
# Rename columns
dict_columns = {'fl_date': 'date', 
                'origin': 'dep_airport', 
                'origin_city_name': 'dep_city', 
                'dest': 'dest_airport', 
                'dest_city_name': 'dest_city',
                'cancelled': 'fl_type',
                'cancellation_code': 'canc_desc',
                'actual_elapsed_time': 'elapsed_time', 
                'carrier_delay': 'Carrier',
                'weather_delay': 'Weather', 
                'nas_delay': 'NAS', 
                'security_delay': 'Security', 
                'late_aircraft_delay': 'Late Aircraft'}


df2.rename(columns=dict_columns, errors='raise', inplace=True)

# %%
# Convert flight date to datetime data type
df2['date'] = pd.to_datetime(df2['date'])

# %%
# Convert columns from numeric to object types and pad zeroes
columns = ['crs_dep_time', 'crs_arr_time']

converter = (lambda x: x.astype(str)
                        .str.zfill(4)
                        .str.replace('2400', '0000')
               if x.name in columns else x)

df2 = df2.apply(converter)

# %%
# Convert columns to time timestamp
for column in columns:
    df2[column] = df2[column].apply(lambda x: datetime.strptime(x, '%H%M').time())

# %%
# Apply timedelta
time_diff = lambda x: datetime.combine(date.min, x)
df2['crs_elapsed_time'] = (df2['crs_arr_time'].apply(time_diff) 
                           - df2['crs_dep_time'].apply(time_diff))

# %%
# Convert to minutes
ls_minutes = []
for item in df2['crs_elapsed_time']:
    ls_minutes.append(item.total_seconds()/60)

df2['crs_elapsed_time'] = ls_minutes

# %%
# Convert to int
columns = ['crs_elapsed_time', 'distance']
converter = (lambda x: x.astype(int) if x.name in columns else x)

df2 = df2.apply(converter)

# %%
df2.head()
# Out:
#         date dep_airport         dep_city dest_airport          dest_city  \
# 0 2018-12-28         IAH      Houston, TX          STL      St. Louis, MO
# 1 2016-08-09         ATL      Atlanta, GA          PHL   Philadelphia, PA
# 2 2018-09-14         CLT    Charlotte, NC          ILM     Wilmington, NC
# 3 2019-04-25         LAX  Los Angeles, CA          SFO  San Francisco, CA
# 4 2017-01-09         RNO         Reno, NV          LAX    Los Angeles, CA
#
#   crs_dep_time  dep_time  dep_delay  taxi_out  wheels_off  wheels_on  taxi_in  \
# 0     14:55:00       NaN        NaN       NaN         NaN        NaN      NaN
# 1     16:36:00       NaN        NaN       NaN         NaN        NaN      NaN
# 2     14:27:00       NaN        NaN       NaN         NaN        NaN      NaN
# 3     08:15:00       NaN        NaN       NaN         NaN        NaN      NaN
# 4     19:40:00       NaN        NaN       NaN         NaN        NaN      NaN
#
#   crs_arr_time  arr_time  arr_delay  fl_type canc_desc  diverted  \
# 0     17:02:00       NaN        NaN      1.0         A       0.0
# 1     18:56:00       NaN        NaN      1.0         A       0.0
# 2     15:26:00       NaN        NaN      1.0         B       0.0
# 3     09:40:00       NaN        NaN      1.0         A       0.0
# 4     21:19:00       NaN        NaN      1.0         C       0.0
#
#    crs_elapsed_time  elapsed_time  air_time  distance  Carrier  Weather  NAS  \
# 0             127.0           NaN       NaN     667.0      NaN      NaN  NaN
# 1             140.0           NaN       NaN     666.0      NaN      NaN  NaN
# 2              59.0           NaN       NaN     185.0      NaN      NaN  NaN
# 3              85.0           NaN       NaN     337.0      NaN      NaN  NaN
# 4              99.0           NaN       NaN     391.0      NaN      NaN  NaN
#
#    Security  Late Aircraft  unnamed: 27
# 0       NaN            NaN          NaN
# 1       NaN            NaN          NaN
# 2       NaN            NaN          NaN
# 3       NaN            NaN          NaN
# 4       NaN            NaN          NaN

# %%
# Assign nulls to columns not used
df2[['dep_time', 'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 
     'taxi_in', 'arr_time', 'arr_delay', 'elapsed_time', 'air_time',
     'Carrier', 'Weather', 'NAS', 'Security', 'Late Aircraft']] = np.nan

# %%
# Replace cancellation codes with descriptions
dict_desc = {'A': 'Carrier',
             'B': 'Weather',
             'C': 'NAS',
             'D': 'Security'}

df2['canc_desc'].replace(dict_desc, inplace=True)

# %%
df2.head()
# Out:
#         date dep_airport         dep_city dest_airport          dest_city  \
# 0 2018-12-28         IAH      Houston, TX          STL      St. Louis, MO
# 1 2016-08-09         ATL      Atlanta, GA          PHL   Philadelphia, PA
# 2 2018-09-14         CLT    Charlotte, NC          ILM     Wilmington, NC
# 3 2019-04-25         LAX  Los Angeles, CA          SFO  San Francisco, CA
# 4 2017-01-09         RNO         Reno, NV          LAX    Los Angeles, CA
#
#   crs_dep_time  dep_time  dep_delay  taxi_out  wheels_off  wheels_on  taxi_in  \
# 0     14:55:00       NaN        NaN       NaN         NaN        NaN      NaN
# 1     16:36:00       NaN        NaN       NaN         NaN        NaN      NaN
# 2     14:27:00       NaN        NaN       NaN         NaN        NaN      NaN
# 3     08:15:00       NaN        NaN       NaN         NaN        NaN      NaN
# 4     19:40:00       NaN        NaN       NaN         NaN        NaN      NaN
#
#   crs_arr_time  arr_time  arr_delay  fl_type canc_desc  diverted  \
# 0     17:02:00       NaN        NaN      1.0   Carrier       0.0
# 1     18:56:00       NaN        NaN      1.0   Carrier       0.0
# 2     15:26:00       NaN        NaN      1.0   Weather       0.0
# 3     09:40:00       NaN        NaN      1.0   Carrier       0.0
# 4     21:19:00       NaN        NaN      1.0       NAS       0.0
#
#    crs_elapsed_time  elapsed_time  air_time  distance  Carrier  Weather  NAS  \
# 0             127.0           NaN       NaN     667.0      NaN      NaN  NaN
# 1             140.0           NaN       NaN     666.0      NaN      NaN  NaN
# 2              59.0           NaN       NaN     185.0      NaN      NaN  NaN
# 3              85.0           NaN       NaN     337.0      NaN      NaN  NaN
# 4              99.0           NaN       NaN     391.0      NaN      NaN  NaN
#
#    Security  Late Aircraft  unnamed: 27
# 0       NaN            NaN          NaN
# 1       NaN            NaN          NaN
# 2       NaN            NaN          NaN
# 3       NaN            NaN          NaN
# 4       NaN            NaN          NaN

# %%
# Append dataframe
flights = df1.append(df2).reset_index(drop=True)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498818 entries, 0 to 498817
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              498818 non-null  datetime64[ns]
#  1   dep_airport       498818 non-null  object
#  2   dep_city          498818 non-null  object
#  3   dest_airport      498818 non-null  object
#  4   dest_city         498818 non-null  object
#  5   crs_dep_time      498818 non-null  object
#  6   dep_time          491127 non-null  object
#  7   dep_delay         491127 non-null  float64
#  8   taxi_out          491127 non-null  float64
#  9   wheels_off        491127 non-null  object
#  10  wheels_on         491127 non-null  object
#  11  taxi_in           491127 non-null  float64
#  12  crs_arr_time      498818 non-null  object
#  13  arr_time          491127 non-null  object
#  14  arr_delay         491127 non-null  float64
#  15  fl_type           498818 non-null  float64
#  16  canc_desc         7691 non-null    object
#  17  diverted          498818 non-null  float64
#  18  crs_elapsed_time  498818 non-null  float64
#  19  elapsed_time      491127 non-null  float64
#  20  air_time          491127 non-null  float64
#  21  distance          498818 non-null  float64
#  22  Carrier           91316 non-null   float64
#  23  Weather           91316 non-null   float64
#  24  NAS               91316 non-null   float64
#  25  Security          91316 non-null   float64
#  26  Late Aircraft     91316 non-null   float64
#  27  unnamed: 27       0 non-null       float64
# dtypes: datetime64[ns](1), float64(16), object(11)
# memory usage: 106.6+ MB

# %%
# Split columns
flights[['dep_city', 'dep_state']] = flights.dep_city.str.split(',', expand=True)
flights[['dest_city', 'dest_state']] = flights.dest_city.str.split(',', expand=True)

# %%
# Strip columns
flights['dep_state'] = flights.dep_state.str.strip()
flights['dest_state'] = flights.dest_state.str.strip()

# %%
# Label cancelled and diverted column to True or False
ls_types = []
    
for item, delay in zip(flights.fl_type, flights.arr_delay):
    if item == 1:
        ls_types.append('Cancelled')
    elif delay < 15:
        ls_types.append('On time')
    else:
        ls_types.append('Delayed')
        
flights['fl_type'] = ls_types

# %%
# Break down datetime objects
flights['year'] = flights['date'].apply(lambda x: x.year)

flights['month'] = flights['date'].apply(lambda x: x.month)

flights['weekday'] = flights['date'].apply(lambda x: x.isoweekday())

# %%
# Reorder columns and ignore unnecessary column 'unnamed: 27'
ordered_columns = ['date', 'year', 'month', 'weekday', 
                   'dep_airport', 'dep_city', 'dep_state', 
                   'dest_airport', 'dest_city', 'dest_state', 
                   'crs_dep_time', 'dep_time', 'dep_delay', 
                   'taxi_out', 'wheels_off', 'wheels_on', 
                   'taxi_in', 'crs_arr_time', 'arr_time', 
                   'arr_delay', 'fl_type', 'canc_desc', 
                   'crs_elapsed_time', 'elapsed_time', 
                   'air_time', 'distance', 'Carrier', 
                   'Weather', 'NAS', 'Security',
                   'Late Aircraft']

flights = flights[ordered_columns]

# %%
flights.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498818 entries, 0 to 498817
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              498818 non-null  datetime64[ns]
#  1   year              498818 non-null  int64
#  2   month             498818 non-null  int64
#  3   weekday           498818 non-null  int64
#  4   dep_airport       498818 non-null  object
#  5   dep_city          498818 non-null  object
#  6   dep_state         498818 non-null  object
#  7   dest_airport      498818 non-null  object
#  8   dest_city         498818 non-null  object
#  9   dest_state        498818 non-null  object
#  10  crs_dep_time      498818 non-null  object
#  11  dep_time          491127 non-null  object
#  12  dep_delay         491127 non-null  float64
#  13  taxi_out          491127 non-null  float64
#  14  wheels_off        491127 non-null  object
#  15  wheels_on         491127 non-null  object
#  16  taxi_in           491127 non-null  float64
#  17  crs_arr_time      498818 non-null  object
#  18  arr_time          491127 non-null  object
#  19  arr_delay         491127 non-null  float64
#  20  fl_type           498818 non-null  object
#  21  canc_desc         7691 non-null    object
#  22  crs_elapsed_time  498818 non-null  float64
#  23  elapsed_time      491127 non-null  float64
#  24  air_time          491127 non-null  float64
#  25  distance          498818 non-null  float64
#  26  Carrier           91316 non-null   float64
#  27  Weather           91316 non-null   float64
#  28  NAS               91316 non-null   float64
#  29  Security          91316 non-null   float64
#  30  Late Aircraft     91316 non-null   float64
# dtypes: datetime64[ns](1), float64(13), int64(3), object(14)
# memory usage: 118.0+ MB

# %%
# Write to csv
dest_folder = '/Users/thaysmartinez/Documents/Flights Data Exploration/'
extension = '.csv'
flights.to_csv('%sflights%s' % (dest_folder, extension), index=False, encoding='utf-8')
